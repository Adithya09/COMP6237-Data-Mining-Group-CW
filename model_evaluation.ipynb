# %%
import pandas as pd
import model_selection_pipeline as pipeline
from joblib import dump
from imblearn.over_sampling import SMOTE
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')
# Out:
# C:\Users\padit\AppData\Local\Temp\ipykernel_11416\2436019669.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('train.csv')

# %%
feature_list = ['Occupation', 'Payment_Behaviour', 'Payment_of_Min_Amount', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan']
pipeline.run_ml_pipeline(df, feature_list, 0.2)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 1/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=  13.9s
# [CV 2/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=  12.5s
# [CV 3/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=  11.7s
# [CV 4/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=  11.8s
# [CV 5/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=  11.8s
# [CV 1/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=lbfgs;, score=nan total time=  13.6s
# ...

# %% [markdown]
# ### Training and testing on a subset of the data

# %%
subset_df = pd.read_csv('stratified_credit_subset.csv')

# %%
feature_list = ['Occupation', 'Payment_Behaviour', 'Payment_of_Min_Amount', 'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan']
pipeline.run_ml_pipeline(subset_df, feature_list, 0.2)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 1/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=   0.3s
# [CV 2/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END classifier__C=0.01, classifier__penalty=l1, classifier__random_state=42, classifier__solver=lbfgs;, score=nan total time=   0.0s
# ...
