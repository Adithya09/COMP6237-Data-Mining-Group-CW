# %% [markdown]
# # Set Up code

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm.autonotebook import tqdm
import matplotlib.pyplot as plt
import torch
from torch import nn
from sklearn.preprocessing import PowerTransformer
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,\
    HistGradientBoostingClassifier,GradientBoostingClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from torch.utils.data import DataLoader
from xgboost import XGBClassifier
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
# %matplotlib inline
# Out:
# <ipython-input-1-a3195715ac65>:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# %%
#mouting google drive to the notebook to retrive data files - not necessary if running locally
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Setting a PyTorch seed for the rest of the code
torch.manual_seed(71)
torch.cuda.manual_seed(71)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
train_path = r'/content/drive/MyDrive/_shared/Data-Mining/data-clean/train.csv'
# test_path = r'/content/drive/MyDrive/_shared/Data-Mining/data-clean/test.csv' Not used due to lack of labels available
df = pd.read_csv(train_path, low_memory=False)

# %% [markdown]
# # Preparing Data for Models

# %%
df['Credit_Score'] = df['Credit_Score'].map({'Good': 0, 'Poor': 1, 'Standard': 2})

# %%
'''Removing columns that provide any useful information.'''

all_features = df.columns.to_list()
values_to_remove = {'ID', 'Customer_ID', 'Month', 'Name', 'SSN'}
all_features = [x for x in all_features if x not in values_to_remove]
df = df[all_features]
all_features
# Out:
# ['Age',
#  'Occupation',
#  'Annual_Income',
#  'Monthly_Inhand_Salary',
#  'Num_Bank_Accounts',
#  'Num_Credit_Card',
#  'Interest_Rate',
#  'Num_of_Loan',
#  'Type_of_Loan',
#  'Delay_from_due_date',
#  'Num_of_Delayed_Payment',
#  'Changed_Credit_Limit',
#  'Num_Credit_Inquiries',
#  'Credit_Mix',
#  'Outstanding_Debt',
#  'Credit_Utilization_Ratio',
#  'Credit_History_Age',
#  'Payment_of_Min_Amount',
#  'Total_EMI_per_month',
#  'Amount_invested_monthly',
#  'Payment_Behaviour',
#  'Monthly_Balance',
#  'Credit_Score']

# %%
# '''Feature List extracted from Random Forest Classifier feature importance scores in the aonther notebook '''
# feature_list = ['Monthly_Inhand_Salary','Annual_Income', 'Amount_invested_monthly','Num_of_Delayed_Payment', 'Num_Bank_Accounts', 'Interest_Rate','Delay_from_due_date','Changed_Credit_Limit','Outstanding_Debt','Credit_History_Age', 'Credit_Score']

# df = df[feature_list]

# %%
obj_to_num_dict={}
obj_to_num_dict['Month']={'January' : 1,
                          'February' : 2,
                          'March' : 3,
                          'April' : 4,
                          'May' : 5,
                          'June' : 6,
                          'July' : 7,
                          'August': 8,
                          'September':9,
                          'October':10,
                          'November':11,
                          'December':12}
num_to_obj_dict={}
def convert_str_to_num(df=df):
    """
    Function to convert all categorical columns in the dataframe to
    numerical values (starting from 0) while storing the mappings.

    Params:
        df - Pandas DataFrame

    Output:
        Returns the modified dataframe with all cotegorical columns coverted to numerical values.
    """

    # df=pd.get_dummies(df,columns=['Occupation'])
    for column in (df.select_dtypes(include='object').columns):

        obj_to_num_dict[column]={}
        num_to_obj_dict[column]={}

        for n,unique_value in enumerate(df[column].unique()):
            df[column]=df[column].replace( unique_value , n)
            obj_to_num_dict[ column][unique_value]= n
            num_to_obj_dict[ column][n+1]= unique_value

        df[column]=df[column].astype('uint8')

    return df

# %%
df = convert_str_to_num(df)

# %%
df.head(10)
# Out:
#    Monthly_Inhand_Salary  Annual_Income  Amount_invested_monthly  \
# 0            1824.843333       19114.12                21.465380
# 1            1824.843333       19114.12                21.465380
# 2            1824.843333       19114.12                21.465380
# 3            1824.843333       19114.12                21.465380
# 4            1824.843333       19114.12                21.465380
# 5            1824.843333       19114.12                21.465380
# 6            1824.843333       19114.12                21.465380
# 7            1824.843333       19114.12                21.465380
# 8            3037.986667       34847.84                39.684018
# 9            3037.986667       34847.84                39.684018
#
#    Num_of_Delayed_Payment  Num_Bank_Accounts  Interest_Rate  \
# 0                     7.0                3.0            3.0
# 1                     4.0                3.0            3.0
# 2                     7.0                3.0            3.0
# 3                     4.0                3.0            3.0
# 4                     4.0                3.0            3.0
# 5                     4.0                3.0            3.0
# 6                     8.0                3.0            3.0
# 7                     6.0                3.0            3.0
# 8                     4.0                2.0            6.0
# 9                     1.0                2.0            6.0
#
#    Delay_from_due_date  Changed_Credit_Limit  Outstanding_Debt  \
# 0                  3.0                 11.27            809.98
# 1                  3.0                 11.27            809.98
# 2                  3.0                 11.27            809.98
# 3                  5.0                  6.27            809.98
# 4                  6.0                 11.27            809.98
# 5                  8.0                  9.27            809.98
# 6                  3.0                 11.27            809.98
# 7                  3.0                 11.27            809.98
# 8                  3.0                  5.42            605.03
# 9                  7.0                  7.42            605.03
#
#    Credit_History_Age  Credit_Score
# 0               265.0             0
# 1               266.0             0
# 2               267.0             0
# 3               268.0             0
# 4               269.0             0
# 5               270.0             0
# 6               271.0             0
# 7               272.0             2
# 8               319.0             2
# 9               320.0             0

# %% [markdown]
# ## Applying SMOTE

# %%
def split_and_rebalance(dataframe = df, test_size = 0.2):
    """
    Takes in a dataframe and oversamples minority classes using SMOTE,
    based on a ratio provided in wider literature (explained in the report).

    Params:
        df - dataframe with the target data
        test_size - Ratio of the testing data split (0-1)

    Output:
        x_train - Dataframe with the training data
        x_test - Dataframe with the testing data
        y_train - Series with the target values for traning data
        y_test - Series with target values for test data

    """

    y = dataframe['Credit_Score']
    X = dataframe.drop('Credit_Score', axis=1)  # Replace 'label_column_name' with the actual column name of the label

    # splitting with 30% of the data being test data
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=71)

    strategy = {0: 27000, 1: 27000}
    sampler = SMOTE(sampling_strategy=strategy)

    x_train, y_train = sampler.fit_resample(x_train, y_train)
    print(y_train.value_counts())

    return x_train, x_test, y_train, y_test

# %% [markdown]
# # Training Classifiers for the Ensemble

# %%
def train_model(estimator,df,target='Credit_Score',test_size=0.2):
    """
    Takes in target classifiers, splits and trains on balanced data (using SMOTE)
    and returns the trained classifier and its classification report.

    Params:
        estimator - Name of the Classifier
        df - dataframe with the target data
        target - The target variable to predict
        test_size - Ratio of the testing data split (0-1)
        report - Toggle classication report being returned
        random_state - ,return_pipeline=False

    Output:
        model_pipeline - Trained model pipeline
        report_test - Full classification report proviiding precision, recall, accuracy and F1 score

    """

    x_train, x_test, y_train, y_test = split_and_rebalance(df, test_size)

    model_pipeline=make_pipeline(None,estimator)
    model_pipeline.fit(x_train,y_train)


    print(f'test report:\n{classification_report(model_pipeline.predict(x_test),y_test)}')
    print(f'train report:\n{classification_report(model_pipeline.predict(x_train), y_train)}')


    report_test=pd.DataFrame.from_dict(classification_report(
    model_pipeline.predict(x_test),y_test,output_dict=True))

    return model_pipeline,report_test

# %%
models_and_reports = {}

# %%
params = {
 'base_score': 0.5,
 'colsample_bylevel': 1,
 'colsample_bytree': 1,
 'gamma': 1,
 'learning_rate': 1e-1,
 'max_delta_step': 1,
 'max_depth': 10,
 'min_child_weight': 1,
 'n_estimators': 232,
 'objective': 'binary:logistic',
 'reg_alpha': 9e-1,
 'reg_lambda': 0.8,
 'scale_pos_weight': 1,
 'seed': 21,
 'silent': 1,
 'subsample': 1,
}

xgBoost = XGBClassifier(**params)

# %%
models_and_reports['RandomForestClassifier'] = train_model(
    estimator=RandomForestClassifier(max_depth=25,n_estimators=100,random_state=3,
                                     min_samples_split=3,criterion='entropy',
                                     bootstrap=True,n_jobs=-1),
                                        df=df,test_size=0.3)
# Out:
# Credit_Score
# 2    37344
# 1    27000
# 0    27000
# Name: count, dtype: int64
# test report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74      6466
#            1       0.83      0.79      0.81      9202
#            2       0.76      0.84      0.80     14332
#
#     accuracy                           0.79     30000
#    macro avg       0.80      0.77      0.78     30000
# weighted avg       0.79      0.79      0.79     30000
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96     29047
#            1       0.98      0.96      0.97     27556
#            2       0.92      0.99      0.95     34741
#
#     accuracy                           0.96     91344
#    macro avg       0.96      0.96      0.96     91344
# weighted avg       0.96      0.96      0.96     91344

# %%
models_and_reports['OneVsRestClassifier'] = train_model(
    estimator=OneVsRestClassifier(RandomForestClassifier(max_depth=22,n_estimators=100,random_state=3,
                                     min_samples_split=3,criterion='entropy',
                                     bootstrap=True,n_jobs=-1)),
                                        df=df,test_size=0.3)  # - F1 -> 0.8012
# Out:
# Credit_Score
# 2    37344
# 1    27000
# 0    27000
# Name: count, dtype: int64
# test report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.66      0.73      6582
#            1       0.83      0.79      0.81      9162
#            2       0.76      0.84      0.80     14256
#
#     accuracy                           0.79     30000
#    macro avg       0.80      0.77      0.78     30000
# weighted avg       0.79      0.79      0.79     30000
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94     29513
#            1       0.95      0.93      0.94     27606
#            2       0.89      0.97      0.92     34225
#
#     accuracy                           0.93     91344
#    macro avg       0.94      0.93      0.94     91344
# weighted avg       0.94      0.93      0.93     91344

# %%
models_and_reports['XGBoost'] = train_model(estimator=xgBoost, df=df,test_size=0.3)
# Out:
# Credit_Score
# 2    37344
# 1    27000
# 0    27000
# Name: count, dtype: int64
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [17:08:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "scale_pos_weight", "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# test report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.59      0.67      7069
#            1       0.78      0.77      0.77      8843
#            2       0.72      0.81      0.76     14088
#
#     accuracy                           0.75     30000
#    macro avg       0.76      0.72      0.74     30000
# weighted avg       0.75      0.75      0.74     30000
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85     30770
#            1       0.85      0.85      0.85     26967
#            2       0.77      0.86      0.81     33607
#
#     accuracy                           0.83     91344
#    macro avg       0.84      0.83      0.84     91344
# weighted avg       0.84      0.83      0.84     91344

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from catboost import CatBoostClassifier

models_and_reports['CatBoostClassifier'] = train_model(
    estimator=OneVsRestClassifier(CatBoostClassifier(iterations=300, depth=10, learning_rate=0.01, loss_function='MultiClass')),
                    df=df,test_size=0.2)
# Out:
# Credit_Score
# 2    42648
# 0    27000
# 1    27000
# Name: count, dtype: int64
# 0:	learn: 0.6886313	total: 183ms	remaining: 54.8s
# 1:	learn: 0.6840636	total: 311ms	remaining: 46.3s
# 2:	learn: 0.6796233	total: 575ms	remaining: 56.9s
# 3:	learn: 0.6752734	total: 850ms	remaining: 1m 2s
# 4:	learn: 0.6709321	total: 972ms	remaining: 57.3s
# 5:	learn: 0.6666420	total: 1.11s	remaining: 54.3s
# 6:	learn: 0.6625649	total: 1.23s	remaining: 51.5s
# 7:	learn: 0.6584840	total: 1.37s	remaining: 50s
# 8:	learn: 0.6545134	total: 1.5s	remaining: 48.3s
# 9:	learn: 0.6505684	total: 1.7s	remaining: 49.3s
# 10:	learn: 0.6467066	total: 2.02s	remaining: 53s
# 11:	learn: 0.6429129	total: 2.34s	remaining: 56.1s
# 12:	learn: 0.6391611	total: 2.63s	remaining: 58s
# 13:	learn: 0.6354982	total: 2.87s	remaining: 58.6s
# 14:	learn: 0.6319315	total: 3.12s	remaining: 59.2s
# 15:	learn: 0.6284150	total: 3.4s	remaining: 1m
# 16:	learn: 0.6249361	total: 3.69s	remaining: 1m 1s
# 17:	learn: 0.6214967	total: 3.93s	remaining: 1m 1s
# 18:	learn: 0.6181335	total: 4.14s	remaining: 1m 1s
# 19:	learn: 0.6149173	total: 4.38s	remaining: 1m 1s
# 20:	learn: 0.6116995	total: 4.62s	remaining: 1m 1s
# 21:	learn: 0.6085550	total: 4.85s	remaining: 1m 1s
# 22:	learn: 0.6053814	total: 5.09s	remaining: 1m 1s
# 23:	learn: 0.6023876	total: 5.33s	remaining: 1m 1s
# 24:	learn: 0.5992905	total: 5.75s	remaining: 1m 3s
# 25:	learn: 0.5963682	total: 6.06s	remaining: 1m 3s
# 26:	learn: 0.5934384	total: 6.37s	remaining: 1m 4s
# 27:	learn: 0.5905416	total: 6.61s	remaining: 1m 4s
# 28:	learn: 0.5876747	total: 6.85s	remaining: 1m 4s
# 29:	learn: 0.5849361	total: 7.13s	remaining: 1m 4s
# 30:	learn: 0.5821961	total: 7.37s	remaining: 1m 3s
# 31:	learn: 0.5795184	total: 7.63s	remaining: 1m 3s
# 32:	learn: 0.5768529	total: 7.9s	remaining: 1m 3s
# 33:	learn: 0.5742503	total: 8.14s	remaining: 1m 3s
# 34:	learn: 0.5716893	total: 8.4s	remaining: 1m 3s
# 35:	learn: 0.5691562	total: 8.72s	remaining: 1m 3s
# 36:	learn: 0.5667048	total: 9.05s	remaining: 1m 4s
# 37:	learn: 0.5642724	total: 9.3s	remaining: 1m 4s
# 38:	learn: 0.5619263	total: 9.61s	remaining: 1m 4s
# 39:	learn: 0.5595224	total: 9.95s	remaining: 1m 4s
# 40:	learn: 0.5571696	total: 10.2s	remaining: 1m 4s
# 41:	learn: 0.5549192	total: 10.5s	remaining: 1m 4s
# 42:	learn: 0.5526656	total: 10.8s	remaining: 1m 4s
# 43:	learn: 0.5504354	total: 11.1s	remaining: 1m 4s
# 44:	learn: 0.5482160	total: 11.4s	remaining: 1m 4s
# 45:	learn: 0.5460509	total: 11.7s	remaining: 1m 4s
# 46:	learn: 0.5439350	total: 12s	remaining: 1m 4s
# 47:	learn: 0.5417690	total: 12.4s	remaining: 1m 4s
# 48:	learn: 0.5396620	total: 12.7s	remaining: 1m 5s
# 49:	learn: 0.5376010	total: 13s	remaining: 1m 5s
# 50:	learn: 0.5356444	total: 13.3s	remaining: 1m 4s
# 51:	learn: 0.5336387	total: 13.5s	remaining: 1m 4s
# 52:	learn: 0.5316556	total: 13.8s	remaining: 1m 4s
# 53:	learn: 0.5297415	total: 14s	remaining: 1m 3s
# 54:	learn: 0.5277701	total: 14.3s	remaining: 1m 3s
# 55:	learn: 0.5258982	total: 14.7s	remaining: 1m 4s
# 56:	learn: 0.5239964	total: 15s	remaining: 1m 3s
# 57:	learn: 0.5222073	total: 15.3s	remaining: 1m 3s
# 58:	learn: 0.5203642	total: 15.6s	remaining: 1m 3s
# 59:	learn: 0.5186488	total: 15.8s	remaining: 1m 3s
# 60:	learn: 0.5168694	total: 16.1s	remaining: 1m 3s
# 61:	learn: 0.5151427	total: 16.3s	remaining: 1m 2s
# 62:	learn: 0.5135118	total: 16.7s	remaining: 1m 2s
# 63:	learn: 0.5118252	total: 17.2s	remaining: 1m 3s
# 64:	learn: 0.5101290	total: 17.6s	remaining: 1m 3s
# 65:	learn: 0.5084683	total: 17.9s	remaining: 1m 3s
# 66:	learn: 0.5068503	total: 18.3s	remaining: 1m 3s
# 67:	learn: 0.5052539	total: 18.6s	remaining: 1m 3s
# 68:	learn: 0.5037361	total: 19s	remaining: 1m 3s
# 69:	learn: 0.5022179	total: 19.4s	remaining: 1m 3s
# 70:	learn: 0.5006288	total: 19.8s	remaining: 1m 4s
# 71:	learn: 0.4991530	total: 20.2s	remaining: 1m 4s
# 72:	learn: 0.4976623	total: 20.6s	remaining: 1m 3s
# 73:	learn: 0.4962114	total: 20.8s	remaining: 1m 3s
# 74:	learn: 0.4947490	total: 21s	remaining: 1m 3s
# 75:	learn: 0.4933516	total: 21.2s	remaining: 1m 2s
# 76:	learn: 0.4919814	total: 21.4s	remaining: 1m 2s
# 77:	learn: 0.4906174	total: 21.6s	remaining: 1m 1s
# 78:	learn: 0.4892571	total: 21.9s	remaining: 1m 1s
# 79:	learn: 0.4878936	total: 22.2s	remaining: 1m
# 80:	learn: 0.4865805	total: 22.5s	remaining: 1m
# 81:	learn: 0.4852913	total: 22.7s	remaining: 1m
# 82:	learn: 0.4839799	total: 23s	remaining: 1m
# 83:	learn: 0.4826370	total: 23.3s	remaining: 59.9s
# 84:	learn: 0.4813672	total: 23.6s	remaining: 59.7s
# 85:	learn: 0.4801207	total: 23.9s	remaining: 59.4s
# 86:	learn: 0.4788811	total: 24.1s	remaining: 59s
# 87:	learn: 0.4776260	total: 24.5s	remaining: 59s
# 88:	learn: 0.4764192	total: 24.8s	remaining: 58.8s
# 89:	learn: 0.4752155	total: 25.2s	remaining: 58.9s
# 90:	learn: 0.4740856	total: 25.5s	remaining: 58.7s
# 91:	learn: 0.4729708	total: 25.9s	remaining: 58.5s
# 92:	learn: 0.4718321	total: 26.2s	remaining: 58.3s
# 93:	learn: 0.4707265	total: 26.5s	remaining: 58.1s
# 94:	learn: 0.4696003	total: 26.8s	remaining: 57.7s
# 95:	learn: 0.4685358	total: 27.1s	remaining: 57.7s
# 96:	learn: 0.4675111	total: 27.4s	remaining: 57.3s
# 97:	learn: 0.4664470	total: 27.8s	remaining: 57.2s
# 98:	learn: 0.4654277	total: 28.1s	remaining: 57s
# 99:	learn: 0.4644157	total: 28.3s	remaining: 56.6s
# 100:	learn: 0.4634098	total: 28.7s	remaining: 56.5s
# 101:	learn: 0.4624078	total: 29.1s	remaining: 56.5s
# 102:	learn: 0.4614065	total: 29.4s	remaining: 56.2s
# 103:	learn: 0.4604213	total: 29.6s	remaining: 55.8s
# 104:	learn: 0.4594197	total: 29.9s	remaining: 55.5s
# 105:	learn: 0.4584615	total: 30.2s	remaining: 55.3s
# 106:	learn: 0.4575328	total: 30.5s	remaining: 55s
# 107:	learn: 0.4566349	total: 30.9s	remaining: 55s
# 108:	learn: 0.4556760	total: 31.5s	remaining: 55.2s
# 109:	learn: 0.4547682	total: 32s	remaining: 55.2s
# 110:	learn: 0.4538775	total: 32.5s	remaining: 55.3s
# 111:	learn: 0.4530065	total: 33s	remaining: 55.4s
# 112:	learn: 0.4521375	total: 33.9s	remaining: 56.1s
# 113:	learn: 0.4512899	total: 34.6s	remaining: 56.5s
# 114:	learn: 0.4504564	total: 35.5s	remaining: 57.1s
# 115:	learn: 0.4496390	total: 36.2s	remaining: 57.4s
# 116:	learn: 0.4487870	total: 36.7s	remaining: 57.5s
# 117:	learn: 0.4479909	total: 37.2s	remaining: 57.3s
# 118:	learn: 0.4471465	total: 37.7s	remaining: 57.4s
# 119:	learn: 0.4463537	total: 38.1s	remaining: 57.1s
# 120:	learn: 0.4455824	total: 38.4s	remaining: 56.8s
# 121:	learn: 0.4447926	total: 38.7s	remaining: 56.4s
# 122:	learn: 0.4440355	total: 39s	remaining: 56.1s
# 123:	learn: 0.4432788	total: 39.2s	remaining: 55.6s
# 124:	learn: 0.4424649	total: 39.5s	remaining: 55.3s
# 125:	learn: 0.4417077	total: 39.7s	remaining: 54.9s
# 126:	learn: 0.4409696	total: 40s	remaining: 54.5s
# 127:	learn: 0.4402226	total: 40.2s	remaining: 54s
# 128:	learn: 0.4395174	total: 40.5s	remaining: 53.6s
# 129:	learn: 0.4388079	total: 40.6s	remaining: 53.1s
# 130:	learn: 0.4381259	total: 40.9s	remaining: 52.7s
# 131:	learn: 0.4374522	total: 41.2s	remaining: 52.4s
# 132:	learn: 0.4367626	total: 41.3s	remaining: 51.9s
# 133:	learn: 0.4361113	total: 41.4s	remaining: 51.3s
# 134:	learn: 0.4354126	total: 41.6s	remaining: 50.8s
# 135:	learn: 0.4347331	total: 41.7s	remaining: 50.3s
# 136:	learn: 0.4341068	total: 41.8s	remaining: 49.7s
# 137:	learn: 0.4334414	total: 41.9s	remaining: 49.2s
# 138:	learn: 0.4328256	total: 42.1s	remaining: 48.7s
# 139:	learn: 0.4321812	total: 42.2s	remaining: 48.2s
# 140:	learn: 0.4315898	total: 42.3s	remaining: 47.7s
# 141:	learn: 0.4309629	total: 42.5s	remaining: 47.2s
# 142:	learn: 0.4303427	total: 42.6s	remaining: 46.7s
# 143:	learn: 0.4297097	total: 42.7s	remaining: 46.3s
# 144:	learn: 0.4291441	total: 42.8s	remaining: 45.8s
# 145:	learn: 0.4285597	total: 42.9s	remaining: 45.3s
# 146:	learn: 0.4279703	total: 43.1s	remaining: 44.8s
# 147:	learn: 0.4273974	total: 43.2s	remaining: 44.4s
# 148:	learn: 0.4268244	total: 43.3s	remaining: 43.9s
# 149:	learn: 0.4262594	total: 43.5s	remaining: 43.5s
# 150:	learn: 0.4256909	total: 43.6s	remaining: 43s
# 151:	learn: 0.4250803	total: 43.7s	remaining: 42.5s
# 152:	learn: 0.4245452	total: 43.8s	remaining: 42.1s
# 153:	learn: 0.4240051	total: 43.9s	remaining: 41.7s
# 154:	learn: 0.4234907	total: 44.1s	remaining: 41.2s
# 155:	learn: 0.4229061	total: 44.2s	remaining: 40.8s
# 156:	learn: 0.4223944	total: 44.3s	remaining: 40.4s
# 157:	learn: 0.4218847	total: 44.5s	remaining: 40s
# 158:	learn: 0.4213242	total: 44.6s	remaining: 39.5s
# 159:	learn: 0.4208512	total: 44.7s	remaining: 39.1s
# 160:	learn: 0.4203663	total: 44.8s	remaining: 38.7s
# 161:	learn: 0.4198666	total: 45s	remaining: 38.3s
# 162:	learn: 0.4194157	total: 45.1s	remaining: 37.9s
# 163:	learn: 0.4189041	total: 45.2s	remaining: 37.5s
# 164:	learn: 0.4184651	total: 45.3s	remaining: 37.1s
# 165:	learn: 0.4180284	total: 45.5s	remaining: 36.7s
# 166:	learn: 0.4175646	total: 45.6s	remaining: 36.3s
# 167:	learn: 0.4170937	total: 45.7s	remaining: 35.9s
# 168:	learn: 0.4166489	total: 45.8s	remaining: 35.5s
# 169:	learn: 0.4162199	total: 46s	remaining: 35.1s
# 170:	learn: 0.4157857	total: 46.1s	remaining: 34.8s
# 171:	learn: 0.4153036	total: 46.2s	remaining: 34.4s
# 172:	learn: 0.4148692	total: 46.4s	remaining: 34s
# 173:	learn: 0.4144184	total: 46.5s	remaining: 33.7s
# 174:	learn: 0.4139767	total: 46.6s	remaining: 33.3s
# 175:	learn: 0.4135782	total: 46.7s	remaining: 32.9s
# 176:	learn: 0.4131590	total: 46.8s	remaining: 32.6s
# 177:	learn: 0.4127482	total: 47s	remaining: 32.2s
# 178:	learn: 0.4123504	total: 47.1s	remaining: 31.8s
# 179:	learn: 0.4119481	total: 47.2s	remaining: 31.5s
# 180:	learn: 0.4115456	total: 47.4s	remaining: 31.1s
# 181:	learn: 0.4111702	total: 47.5s	remaining: 30.8s
# 182:	learn: 0.4107430	total: 47.6s	remaining: 30.4s
# 183:	learn: 0.4103973	total: 47.7s	remaining: 30.1s
# 184:	learn: 0.4100036	total: 47.8s	remaining: 29.7s
# 185:	learn: 0.4096542	total: 48s	remaining: 29.4s
# 186:	learn: 0.4092766	total: 48.2s	remaining: 29.1s
# 187:	learn: 0.4089113	total: 48.4s	remaining: 28.8s
# 188:	learn: 0.4085223	total: 48.6s	remaining: 28.6s
# 189:	learn: 0.4081775	total: 48.8s	remaining: 28.3s
# 190:	learn: 0.4078182	total: 49.1s	remaining: 28s
# 191:	learn: 0.4074170	total: 49.3s	remaining: 27.8s
# 192:	learn: 0.4070993	total: 49.6s	remaining: 27.5s
# 193:	learn: 0.4067390	total: 49.8s	remaining: 27.2s
# 194:	learn: 0.4064087	total: 50s	remaining: 26.9s
# 195:	learn: 0.4060934	total: 50.2s	remaining: 26.7s
# 196:	learn: 0.4057773	total: 50.5s	remaining: 26.4s
# 197:	learn: 0.4054630	total: 50.7s	remaining: 26.1s
# 198:	learn: 0.4051177	total: 50.9s	remaining: 25.9s
# 199:	learn: 0.4047617	total: 51.2s	remaining: 25.6s
# 200:	learn: 0.4044616	total: 51.4s	remaining: 25.3s
# 201:	learn: 0.4041543	total: 51.6s	remaining: 25s
# 202:	learn: 0.4038278	total: 51.8s	remaining: 24.8s
# 203:	learn: 0.4035002	total: 52s	remaining: 24.5s
# 204:	learn: 0.4031743	total: 52.1s	remaining: 24.2s
# 205:	learn: 0.4028966	total: 52.2s	remaining: 23.8s
# 206:	learn: 0.4025832	total: 52.4s	remaining: 23.5s
# 207:	learn: 0.4022495	total: 52.5s	remaining: 23.2s
# 208:	learn: 0.4019173	total: 52.6s	remaining: 22.9s
# 209:	learn: 0.4016384	total: 52.8s	remaining: 22.6s
# 210:	learn: 0.4013478	total: 52.9s	remaining: 22.3s
# 211:	learn: 0.4010826	total: 53s	remaining: 22s
# 212:	learn: 0.4008244	total: 53.1s	remaining: 21.7s
# 213:	learn: 0.4005218	total: 53.3s	remaining: 21.4s
# 214:	learn: 0.4002405	total: 53.4s	remaining: 21.1s
# 215:	learn: 0.3999664	total: 53.5s	remaining: 20.8s
# 216:	learn: 0.3997337	total: 53.6s	remaining: 20.5s
# 217:	learn: 0.3994602	total: 53.8s	remaining: 20.2s
# 218:	learn: 0.3991769	total: 53.9s	remaining: 19.9s
# 219:	learn: 0.3989182	total: 54s	remaining: 19.6s
# 220:	learn: 0.3986340	total: 54.1s	remaining: 19.3s
# 221:	learn: 0.3983691	total: 54.2s	remaining: 19.1s
# 222:	learn: 0.3981016	total: 54.4s	remaining: 18.8s
# 223:	learn: 0.3978331	total: 54.5s	remaining: 18.5s
# 224:	learn: 0.3975750	total: 54.6s	remaining: 18.2s
# 225:	learn: 0.3973356	total: 54.8s	remaining: 17.9s
# 226:	learn: 0.3971099	total: 54.9s	remaining: 17.6s
# 227:	learn: 0.3968700	total: 55s	remaining: 17.4s
# 228:	learn: 0.3966149	total: 55.1s	remaining: 17.1s
# 229:	learn: 0.3963843	total: 55.2s	remaining: 16.8s
# 230:	learn: 0.3961216	total: 55.4s	remaining: 16.5s
# 231:	learn: 0.3959186	total: 55.5s	remaining: 16.3s
# 232:	learn: 0.3956736	total: 55.6s	remaining: 16s
# 233:	learn: 0.3954352	total: 55.7s	remaining: 15.7s
# 234:	learn: 0.3951785	total: 55.9s	remaining: 15.5s
# 235:	learn: 0.3949587	total: 56s	remaining: 15.2s
# 236:	learn: 0.3947520	total: 56.1s	remaining: 14.9s
# 237:	learn: 0.3945197	total: 56.2s	remaining: 14.6s
# 238:	learn: 0.3942600	total: 56.4s	remaining: 14.4s
# 239:	learn: 0.3939927	total: 56.5s	remaining: 14.1s
# 240:	learn: 0.3937153	total: 56.6s	remaining: 13.9s
# 241:	learn: 0.3934228	total: 56.8s	remaining: 13.6s
# 242:	learn: 0.3931761	total: 56.9s	remaining: 13.3s
# 243:	learn: 0.3929642	total: 57s	remaining: 13.1s
# 244:	learn: 0.3927611	total: 57.1s	remaining: 12.8s
# 245:	learn: 0.3926016	total: 57.3s	remaining: 12.6s
# 246:	learn: 0.3924036	total: 57.4s	remaining: 12.3s
# 247:	learn: 0.3921607	total: 57.5s	remaining: 12.1s
# 248:	learn: 0.3919215	total: 57.6s	remaining: 11.8s
# 249:	learn: 0.3917037	total: 57.8s	remaining: 11.6s
# 250:	learn: 0.3915140	total: 57.9s	remaining: 11.3s
# 251:	learn: 0.3913048	total: 58s	remaining: 11s
# 252:	learn: 0.3910909	total: 58.1s	remaining: 10.8s
# 253:	learn: 0.3908902	total: 58.3s	remaining: 10.6s
# 254:	learn: 0.3906934	total: 58.4s	remaining: 10.3s
# 255:	learn: 0.3904830	total: 58.5s	remaining: 10.1s
# 256:	learn: 0.3902753	total: 58.7s	remaining: 9.81s
# 257:	learn: 0.3901002	total: 58.8s	remaining: 9.57s
# 258:	learn: 0.3899229	total: 58.9s	remaining: 9.32s
# 259:	learn: 0.3896616	total: 59s	remaining: 9.08s
# 260:	learn: 0.3894830	total: 59.1s	remaining: 8.84s
# 261:	learn: 0.3892712	total: 59.3s	remaining: 8.6s
# 262:	learn: 0.3891070	total: 59.4s	remaining: 8.36s
# 263:	learn: 0.3888702	total: 59.5s	remaining: 8.12s
# 264:	learn: 0.3886646	total: 59.7s	remaining: 7.88s
# 265:	learn: 0.3884638	total: 59.8s	remaining: 7.64s
# 266:	learn: 0.3882998	total: 59.9s	remaining: 7.4s
# 267:	learn: 0.3881097	total: 1m	remaining: 7.17s
# 268:	learn: 0.3879379	total: 1m	remaining: 6.93s
# 269:	learn: 0.3877819	total: 1m	remaining: 6.7s
# 270:	learn: 0.3875966	total: 1m	remaining: 6.46s
# 271:	learn: 0.3874216	total: 1m	remaining: 6.23s
# 272:	learn: 0.3872638	total: 1m	remaining: 6s
# 273:	learn: 0.3870721	total: 1m	remaining: 5.77s
# 274:	learn: 0.3868824	total: 1m	remaining: 5.54s
# 275:	learn: 0.3866897	total: 1m 1s	remaining: 5.31s
# 276:	learn: 0.3865178	total: 1m 1s	remaining: 5.08s
# 277:	learn: 0.3863470	total: 1m 1s	remaining: 4.85s
# 278:	learn: 0.3861752	total: 1m 1s	remaining: 4.62s
# 279:	learn: 0.3860232	total: 1m 1s	remaining: 4.39s
# 280:	learn: 0.3858621	total: 1m 1s	remaining: 4.17s
# 281:	learn: 0.3856690	total: 1m 1s	remaining: 3.94s
# 282:	learn: 0.3855058	total: 1m 1s	remaining: 3.72s
# 283:	learn: 0.3853427	total: 1m 2s	remaining: 3.5s
# 284:	learn: 0.3851807	total: 1m 2s	remaining: 3.28s
# 285:	learn: 0.3850285	total: 1m 2s	remaining: 3.06s
# 286:	learn: 0.3848507	total: 1m 2s	remaining: 2.85s
# 287:	learn: 0.3846674	total: 1m 3s	remaining: 2.63s
# 288:	learn: 0.3845031	total: 1m 3s	remaining: 2.41s
# 289:	learn: 0.3843406	total: 1m 3s	remaining: 2.19s
# 290:	learn: 0.3842005	total: 1m 3s	remaining: 1.97s
# 291:	learn: 0.3840124	total: 1m 3s	remaining: 1.75s
# 292:	learn: 0.3838747	total: 1m 4s	remaining: 1.53s
# 293:	learn: 0.3837109	total: 1m 4s	remaining: 1.31s
# 294:	learn: 0.3835694	total: 1m 4s	remaining: 1.09s
# 295:	learn: 0.3833595	total: 1m 4s	remaining: 876ms
# 296:	learn: 0.3832294	total: 1m 5s	remaining: 657ms
# 297:	learn: 0.3830923	total: 1m 5s	remaining: 438ms
# 298:	learn: 0.3829478	total: 1m 5s	remaining: 219ms
# 299:	learn: 0.3828132	total: 1m 5s	remaining: 0us
# 0:	learn: 0.6881173	total: 132ms	remaining: 39.5s
# 1:	learn: 0.6831665	total: 252ms	remaining: 37.5s
# 2:	learn: 0.6784182	total: 375ms	remaining: 37.2s
# 3:	learn: 0.6738147	total: 506ms	remaining: 37.4s
# 4:	learn: 0.6692595	total: 627ms	remaining: 37s
# 5:	learn: 0.6646873	total: 748ms	remaining: 36.6s
# 6:	learn: 0.6603417	total: 872ms	remaining: 36.5s
# 7:	learn: 0.6560569	total: 1.01s	remaining: 36.9s
# 8:	learn: 0.6518327	total: 1.14s	remaining: 36.9s
# 9:	learn: 0.6475866	total: 1.26s	remaining: 36.6s
# 10:	learn: 0.6434395	total: 1.4s	remaining: 36.7s
# 11:	learn: 0.6394470	total: 1.52s	remaining: 36.5s
# 12:	learn: 0.6355275	total: 1.65s	remaining: 36.4s
# 13:	learn: 0.6315704	total: 1.76s	remaining: 36.1s
# 14:	learn: 0.6277093	total: 1.89s	remaining: 35.9s
# 15:	learn: 0.6239094	total: 2.03s	remaining: 36s
# 16:	learn: 0.6202235	total: 2.16s	remaining: 36s
# 17:	learn: 0.6165980	total: 2.28s	remaining: 35.8s
# 18:	learn: 0.6130296	total: 2.42s	remaining: 35.7s
# 19:	learn: 0.6096070	total: 2.54s	remaining: 35.5s
# 20:	learn: 0.6061959	total: 2.66s	remaining: 35.4s
# 21:	learn: 0.6028889	total: 2.79s	remaining: 35.3s
# 22:	learn: 0.5995270	total: 2.92s	remaining: 35.1s
# 23:	learn: 0.5962384	total: 3.05s	remaining: 35.1s
# 24:	learn: 0.5930286	total: 3.18s	remaining: 35s
# 25:	learn: 0.5898723	total: 3.31s	remaining: 34.8s
# 26:	learn: 0.5867548	total: 3.44s	remaining: 34.8s
# 27:	learn: 0.5837434	total: 3.56s	remaining: 34.6s
# 28:	learn: 0.5807402	total: 3.68s	remaining: 34.4s
# 29:	learn: 0.5778085	total: 3.81s	remaining: 34.3s
# 30:	learn: 0.5749119	total: 3.94s	remaining: 34.2s
# 31:	learn: 0.5719972	total: 4.07s	remaining: 34.1s
# 32:	learn: 0.5692182	total: 4.21s	remaining: 34s
# 33:	learn: 0.5664253	total: 4.33s	remaining: 33.8s
# 34:	learn: 0.5637683	total: 4.46s	remaining: 33.8s
# 35:	learn: 0.5611662	total: 4.58s	remaining: 33.6s
# 36:	learn: 0.5585879	total: 4.71s	remaining: 33.5s
# 37:	learn: 0.5559218	total: 4.83s	remaining: 33.3s
# 38:	learn: 0.5534055	total: 4.96s	remaining: 33.2s
# 39:	learn: 0.5508902	total: 5.1s	remaining: 33.1s
# 40:	learn: 0.5483887	total: 5.23s	remaining: 33s
# 41:	learn: 0.5459187	total: 5.35s	remaining: 32.9s
# 42:	learn: 0.5435085	total: 5.49s	remaining: 32.8s
# 43:	learn: 0.5411339	total: 5.61s	remaining: 32.6s
# 44:	learn: 0.5387525	total: 5.75s	remaining: 32.6s
# 45:	learn: 0.5365173	total: 5.87s	remaining: 32.4s
# 46:	learn: 0.5342094	total: 6s	remaining: 32.3s
# 47:	learn: 0.5319835	total: 6.14s	remaining: 32.2s
# 48:	learn: 0.5297583	total: 6.27s	remaining: 32.1s
# 49:	learn: 0.5275557	total: 6.4s	remaining: 32s
# 50:	learn: 0.5254150	total: 6.52s	remaining: 31.9s
# 51:	learn: 0.5233414	total: 6.66s	remaining: 31.7s
# 52:	learn: 0.5212235	total: 6.78s	remaining: 31.6s
# 53:	learn: 0.5192750	total: 6.91s	remaining: 31.5s
# 54:	learn: 0.5173546	total: 7.04s	remaining: 31.4s
# 55:	learn: 0.5154714	total: 7.18s	remaining: 31.3s
# 56:	learn: 0.5135761	total: 7.3s	remaining: 31.1s
# 57:	learn: 0.5116322	total: 7.43s	remaining: 31s
# 58:	learn: 0.5098209	total: 7.56s	remaining: 30.9s
# 59:	learn: 0.5080420	total: 7.68s	remaining: 30.7s
# 60:	learn: 0.5062679	total: 7.8s	remaining: 30.6s
# 61:	learn: 0.5044901	total: 7.92s	remaining: 30.4s
# 62:	learn: 0.5028306	total: 8.05s	remaining: 30.3s
# 63:	learn: 0.5010581	total: 8.18s	remaining: 30.2s
# 64:	learn: 0.4994447	total: 8.31s	remaining: 30s
# 65:	learn: 0.4976801	total: 8.44s	remaining: 29.9s
# 66:	learn: 0.4959868	total: 8.56s	remaining: 29.8s
# 67:	learn: 0.4943167	total: 8.68s	remaining: 29.6s
# 68:	learn: 0.4927046	total: 8.81s	remaining: 29.5s
# 69:	learn: 0.4910967	total: 8.93s	remaining: 29.3s
# 70:	learn: 0.4895223	total: 9.06s	remaining: 29.2s
# 71:	learn: 0.4879816	total: 9.18s	remaining: 29.1s
# 72:	learn: 0.4864610	total: 9.32s	remaining: 29s
# 73:	learn: 0.4849426	total: 9.45s	remaining: 28.9s
# 74:	learn: 0.4834990	total: 9.57s	remaining: 28.7s
# 75:	learn: 0.4820472	total: 9.7s	remaining: 28.6s
# 76:	learn: 0.4806672	total: 9.83s	remaining: 28.5s
# 77:	learn: 0.4792750	total: 10.1s	remaining: 28.6s
# 78:	learn: 0.4779263	total: 10.3s	remaining: 28.8s
# 79:	learn: 0.4765061	total: 10.5s	remaining: 28.9s
# 80:	learn: 0.4752103	total: 10.7s	remaining: 29s
# 81:	learn: 0.4739506	total: 11s	remaining: 29.2s
# 82:	learn: 0.4726039	total: 11.2s	remaining: 29.3s
# 83:	learn: 0.4712864	total: 11.4s	remaining: 29.4s
# 84:	learn: 0.4699802	total: 11.6s	remaining: 29.5s
# 85:	learn: 0.4687665	total: 11.9s	remaining: 29.5s
# 86:	learn: 0.4675527	total: 12.1s	remaining: 29.6s
# 87:	learn: 0.4663141	total: 12.3s	remaining: 29.7s
# 88:	learn: 0.4651441	total: 12.5s	remaining: 29.7s
# 89:	learn: 0.4639735	total: 12.8s	remaining: 29.8s
# 90:	learn: 0.4628230	total: 13s	remaining: 29.8s
# 91:	learn: 0.4616965	total: 13.2s	remaining: 29.8s
# 92:	learn: 0.4606405	total: 13.4s	remaining: 29.9s
# 93:	learn: 0.4595396	total: 13.7s	remaining: 30s
# 94:	learn: 0.4584336	total: 13.8s	remaining: 29.8s
# 95:	learn: 0.4573326	total: 13.9s	remaining: 29.6s
# 96:	learn: 0.4562764	total: 14s	remaining: 29.4s
# 97:	learn: 0.4552867	total: 14.2s	remaining: 29.2s
# 98:	learn: 0.4542792	total: 14.3s	remaining: 29s
# 99:	learn: 0.4532681	total: 14.4s	remaining: 28.9s
# 100:	learn: 0.4523499	total: 14.6s	remaining: 28.7s
# 101:	learn: 0.4513854	total: 14.7s	remaining: 28.5s
# 102:	learn: 0.4503645	total: 14.8s	remaining: 28.3s
# 103:	learn: 0.4494252	total: 14.9s	remaining: 28.1s
# 104:	learn: 0.4485194	total: 15.1s	remaining: 28s
# 105:	learn: 0.4475767	total: 15.2s	remaining: 27.8s
# 106:	learn: 0.4466168	total: 15.3s	remaining: 27.6s
# 107:	learn: 0.4456984	total: 15.4s	remaining: 27.4s
# 108:	learn: 0.4448330	total: 15.6s	remaining: 27.3s
# 109:	learn: 0.4439203	total: 15.7s	remaining: 27.1s
# 110:	learn: 0.4431043	total: 15.8s	remaining: 26.9s
# 111:	learn: 0.4422821	total: 15.9s	remaining: 26.8s
# 112:	learn: 0.4413519	total: 16.1s	remaining: 26.6s
# 113:	learn: 0.4404562	total: 16.2s	remaining: 26.4s
# 114:	learn: 0.4395700	total: 16.3s	remaining: 26.2s
# 115:	learn: 0.4387742	total: 16.4s	remaining: 26.1s
# 116:	learn: 0.4380238	total: 16.6s	remaining: 25.9s
# 117:	learn: 0.4371622	total: 16.7s	remaining: 25.8s
# 118:	learn: 0.4362834	total: 16.8s	remaining: 25.6s
# 119:	learn: 0.4355280	total: 16.9s	remaining: 25.4s
# 120:	learn: 0.4347899	total: 17.1s	remaining: 25.3s
# 121:	learn: 0.4339716	total: 17.2s	remaining: 25.1s
# 122:	learn: 0.4332408	total: 17.3s	remaining: 24.9s
# 123:	learn: 0.4324893	total: 17.5s	remaining: 24.8s
# 124:	learn: 0.4317620	total: 17.6s	remaining: 24.6s
# 125:	learn: 0.4310299	total: 17.7s	remaining: 24.5s
# 126:	learn: 0.4303128	total: 17.8s	remaining: 24.3s
# 127:	learn: 0.4295528	total: 18s	remaining: 24.1s
# 128:	learn: 0.4288270	total: 18.1s	remaining: 24s
# 129:	learn: 0.4281366	total: 18.2s	remaining: 23.8s
# 130:	learn: 0.4274097	total: 18.4s	remaining: 23.7s
# 131:	learn: 0.4267875	total: 18.5s	remaining: 23.5s
# 132:	learn: 0.4261187	total: 18.6s	remaining: 23.4s
# 133:	learn: 0.4254854	total: 18.8s	remaining: 23.2s
# 134:	learn: 0.4248814	total: 18.9s	remaining: 23.1s
# 135:	learn: 0.4242431	total: 19s	remaining: 22.9s
# 136:	learn: 0.4236404	total: 19.1s	remaining: 22.8s
# 137:	learn: 0.4230354	total: 19.3s	remaining: 22.6s
# 138:	learn: 0.4224465	total: 19.4s	remaining: 22.5s
# 139:	learn: 0.4218479	total: 19.5s	remaining: 22.3s
# 140:	learn: 0.4212880	total: 19.7s	remaining: 22.2s
# 141:	learn: 0.4206878	total: 19.8s	remaining: 22s
# 142:	learn: 0.4201023	total: 19.9s	remaining: 21.9s
# 143:	learn: 0.4195153	total: 20s	remaining: 21.7s
# 144:	learn: 0.4189560	total: 20.2s	remaining: 21.6s
# 145:	learn: 0.4184137	total: 20.3s	remaining: 21.4s
# 146:	learn: 0.4179236	total: 20.4s	remaining: 21.3s
# 147:	learn: 0.4174309	total: 20.6s	remaining: 21.1s
# 148:	learn: 0.4168712	total: 20.7s	remaining: 21s
# 149:	learn: 0.4163696	total: 20.8s	remaining: 20.8s
# 150:	learn: 0.4158638	total: 21s	remaining: 20.7s
# 151:	learn: 0.4153815	total: 21.1s	remaining: 20.5s
# 152:	learn: 0.4148981	total: 21.2s	remaining: 20.4s
# 153:	learn: 0.4143633	total: 21.3s	remaining: 20.2s
# 154:	learn: 0.4138246	total: 21.5s	remaining: 20.1s
# 155:	learn: 0.4133001	total: 21.6s	remaining: 19.9s
# 156:	learn: 0.4127931	total: 21.7s	remaining: 19.8s
# 157:	learn: 0.4123464	total: 21.9s	remaining: 19.6s
# 158:	learn: 0.4118283	total: 22s	remaining: 19.5s
# 159:	learn: 0.4114026	total: 22.1s	remaining: 19.3s
# 160:	learn: 0.4108982	total: 22.2s	remaining: 19.2s
# 161:	learn: 0.4105081	total: 22.4s	remaining: 19.1s
# 162:	learn: 0.4100631	total: 22.5s	remaining: 18.9s
# 163:	learn: 0.4096115	total: 22.6s	remaining: 18.8s
# 164:	learn: 0.4092074	total: 22.8s	remaining: 18.6s
# 165:	learn: 0.4088112	total: 22.9s	remaining: 18.5s
# 166:	learn: 0.4084265	total: 23s	remaining: 18.3s
# 167:	learn: 0.4079891	total: 23.1s	remaining: 18.2s
# 168:	learn: 0.4075916	total: 23.3s	remaining: 18s
# 169:	learn: 0.4071360	total: 23.4s	remaining: 17.9s
# 170:	learn: 0.4067425	total: 23.5s	remaining: 17.7s
# 171:	learn: 0.4063719	total: 23.6s	remaining: 17.6s
# 172:	learn: 0.4059680	total: 23.9s	remaining: 17.5s
# 173:	learn: 0.4055464	total: 24.1s	remaining: 17.4s
# 174:	learn: 0.4051894	total: 24.3s	remaining: 17.4s
# 175:	learn: 0.4048689	total: 24.6s	remaining: 17.3s
# 176:	learn: 0.4044792	total: 24.8s	remaining: 17.2s
# 177:	learn: 0.4040898	total: 25s	remaining: 17.2s
# 178:	learn: 0.4037402	total: 25.3s	remaining: 17.1s
# 179:	learn: 0.4033479	total: 25.5s	remaining: 17s
# 180:	learn: 0.4029530	total: 25.7s	remaining: 16.9s
# 181:	learn: 0.4025651	total: 26s	remaining: 16.8s
# 182:	learn: 0.4022287	total: 26.2s	remaining: 16.8s
# 183:	learn: 0.4018478	total: 26.4s	remaining: 16.7s
# 184:	learn: 0.4015338	total: 26.7s	remaining: 16.6s
# 185:	learn: 0.4011530	total: 26.9s	remaining: 16.5s
# 186:	learn: 0.4008661	total: 27.2s	remaining: 16.4s
# 187:	learn: 0.4004863	total: 27.4s	remaining: 16.3s
# 188:	learn: 0.4001617	total: 27.6s	remaining: 16.2s
# 189:	learn: 0.3998385	total: 27.7s	remaining: 16s
# 190:	learn: 0.3994639	total: 27.8s	remaining: 15.9s
# 191:	learn: 0.3991532	total: 28s	remaining: 15.7s
# 192:	learn: 0.3988961	total: 28.1s	remaining: 15.6s
# 193:	learn: 0.3985581	total: 28.2s	remaining: 15.4s
# 194:	learn: 0.3982296	total: 28.3s	remaining: 15.3s
# 195:	learn: 0.3979006	total: 28.5s	remaining: 15.1s
# 196:	learn: 0.3976112	total: 28.6s	remaining: 14.9s
# 197:	learn: 0.3972689	total: 28.7s	remaining: 14.8s
# 198:	learn: 0.3970147	total: 28.8s	remaining: 14.6s
# 199:	learn: 0.3967237	total: 29s	remaining: 14.5s
# 200:	learn: 0.3964407	total: 29.1s	remaining: 14.3s
# 201:	learn: 0.3960995	total: 29.2s	remaining: 14.2s
# 202:	learn: 0.3958105	total: 29.4s	remaining: 14s
# 203:	learn: 0.3955400	total: 29.5s	remaining: 13.9s
# 204:	learn: 0.3952412	total: 29.6s	remaining: 13.7s
# 205:	learn: 0.3949438	total: 29.7s	remaining: 13.6s
# 206:	learn: 0.3946873	total: 29.9s	remaining: 13.4s
# 207:	learn: 0.3944487	total: 30s	remaining: 13.3s
# 208:	learn: 0.3942000	total: 30.1s	remaining: 13.1s
# 209:	learn: 0.3938951	total: 30.3s	remaining: 13s
# 210:	learn: 0.3935618	total: 30.4s	remaining: 12.8s
# 211:	learn: 0.3933168	total: 30.5s	remaining: 12.7s
# 212:	learn: 0.3930716	total: 30.6s	remaining: 12.5s
# 213:	learn: 0.3927889	total: 30.8s	remaining: 12.4s
# 214:	learn: 0.3924655	total: 30.9s	remaining: 12.2s
# 215:	learn: 0.3922124	total: 31s	remaining: 12.1s
# 216:	learn: 0.3919375	total: 31.2s	remaining: 11.9s
# 217:	learn: 0.3916221	total: 31.3s	remaining: 11.8s
# 218:	learn: 0.3913520	total: 31.4s	remaining: 11.6s
# 219:	learn: 0.3911354	total: 31.6s	remaining: 11.5s
# 220:	learn: 0.3908702	total: 31.7s	remaining: 11.3s
# 221:	learn: 0.3906312	total: 31.8s	remaining: 11.2s
# 222:	learn: 0.3904112	total: 31.9s	remaining: 11s
# 223:	learn: 0.3902051	total: 32.1s	remaining: 10.9s
# 224:	learn: 0.3900102	total: 32.2s	remaining: 10.7s
# 225:	learn: 0.3897871	total: 32.3s	remaining: 10.6s
# 226:	learn: 0.3895583	total: 32.5s	remaining: 10.4s
# 227:	learn: 0.3893241	total: 32.6s	remaining: 10.3s
# 228:	learn: 0.3891160	total: 32.7s	remaining: 10.1s
# 229:	learn: 0.3889053	total: 32.8s	remaining: 10s
# 230:	learn: 0.3886713	total: 33s	remaining: 9.85s
# 231:	learn: 0.3884118	total: 33.1s	remaining: 9.71s
# 232:	learn: 0.3881536	total: 33.2s	remaining: 9.56s
# 233:	learn: 0.3879116	total: 33.4s	remaining: 9.41s
# 234:	learn: 0.3877228	total: 33.5s	remaining: 9.27s
# 235:	learn: 0.3874506	total: 33.6s	remaining: 9.12s
# 236:	learn: 0.3872228	total: 33.8s	remaining: 8.97s
# 237:	learn: 0.3869966	total: 33.9s	remaining: 8.83s
# 238:	learn: 0.3868275	total: 34s	remaining: 8.68s
# 239:	learn: 0.3866076	total: 34.1s	remaining: 8.54s
# 240:	learn: 0.3863587	total: 34.3s	remaining: 8.39s
# 241:	learn: 0.3861467	total: 34.4s	remaining: 8.24s
# 242:	learn: 0.3859631	total: 34.5s	remaining: 8.1s
# 243:	learn: 0.3857738	total: 34.7s	remaining: 7.95s
# 244:	learn: 0.3855891	total: 34.8s	remaining: 7.81s
# 245:	learn: 0.3854185	total: 34.9s	remaining: 7.66s
# 246:	learn: 0.3851828	total: 35s	remaining: 7.52s
# 247:	learn: 0.3849716	total: 35.2s	remaining: 7.38s
# 248:	learn: 0.3847445	total: 35.3s	remaining: 7.23s
# 249:	learn: 0.3845466	total: 35.4s	remaining: 7.09s
# 250:	learn: 0.3843594	total: 35.6s	remaining: 6.94s
# 251:	learn: 0.3841866	total: 35.7s	remaining: 6.8s
# 252:	learn: 0.3839713	total: 35.8s	remaining: 6.65s
# 253:	learn: 0.3837713	total: 36s	remaining: 6.51s
# 254:	learn: 0.3835993	total: 36.1s	remaining: 6.37s
# 255:	learn: 0.3833739	total: 36.2s	remaining: 6.23s
# 256:	learn: 0.3832230	total: 36.4s	remaining: 6.08s
# 257:	learn: 0.3830037	total: 36.5s	remaining: 5.94s
# 258:	learn: 0.3828268	total: 36.6s	remaining: 5.8s
# 259:	learn: 0.3826675	total: 36.8s	remaining: 5.66s
# 260:	learn: 0.3824432	total: 36.9s	remaining: 5.51s
# 261:	learn: 0.3822799	total: 37s	remaining: 5.37s
# 262:	learn: 0.3821413	total: 37.1s	remaining: 5.22s
# 263:	learn: 0.3819720	total: 37.3s	remaining: 5.08s
# 264:	learn: 0.3817958	total: 37.4s	remaining: 4.94s
# 265:	learn: 0.3816330	total: 37.6s	remaining: 4.81s
# 266:	learn: 0.3814908	total: 37.8s	remaining: 4.68s
# 267:	learn: 0.3812893	total: 38.1s	remaining: 4.55s
# 268:	learn: 0.3811267	total: 38.3s	remaining: 4.42s
# 269:	learn: 0.3809486	total: 38.6s	remaining: 4.29s
# 270:	learn: 0.3807571	total: 38.8s	remaining: 4.15s
# 271:	learn: 0.3805728	total: 39.1s	remaining: 4.02s
# 272:	learn: 0.3804286	total: 39.3s	remaining: 3.88s
# 273:	learn: 0.3802480	total: 39.5s	remaining: 3.75s
# 274:	learn: 0.3801018	total: 39.7s	remaining: 3.61s
# 275:	learn: 0.3799287	total: 40s	remaining: 3.47s
# 276:	learn: 0.3798064	total: 40.2s	remaining: 3.34s
# 277:	learn: 0.3796534	total: 40.5s	remaining: 3.2s
# 278:	learn: 0.3794622	total: 40.7s	remaining: 3.06s
# 279:	learn: 0.3793202	total: 40.9s	remaining: 2.92s
# 280:	learn: 0.3792083	total: 41.1s	remaining: 2.78s
# 281:	learn: 0.3790011	total: 41.2s	remaining: 2.63s
# 282:	learn: 0.3788614	total: 41.4s	remaining: 2.48s
# 283:	learn: 0.3787153	total: 41.5s	remaining: 2.34s
# 284:	learn: 0.3785559	total: 41.6s	remaining: 2.19s
# 285:	learn: 0.3784073	total: 41.7s	remaining: 2.04s
# 286:	learn: 0.3782348	total: 41.9s	remaining: 1.9s
# 287:	learn: 0.3780766	total: 42s	remaining: 1.75s
# 288:	learn: 0.3779498	total: 42.1s	remaining: 1.6s
# 289:	learn: 0.3778458	total: 42.3s	remaining: 1.46s
# 290:	learn: 0.3777187	total: 42.4s	remaining: 1.31s
# 291:	learn: 0.3776020	total: 42.5s	remaining: 1.17s
# 292:	learn: 0.3774757	total: 42.7s	remaining: 1.02s
# 293:	learn: 0.3772760	total: 42.8s	remaining: 873ms
# 294:	learn: 0.3771692	total: 42.9s	remaining: 727ms
# 295:	learn: 0.3770325	total: 43s	remaining: 582ms
# 296:	learn: 0.3768835	total: 43.2s	remaining: 436ms
# 297:	learn: 0.3767513	total: 43.3s	remaining: 291ms
# 298:	learn: 0.3766265	total: 43.4s	remaining: 145ms
# 299:	learn: 0.3764865	total: 43.6s	remaining: 0us
# 0:	learn: 0.6910462	total: 141ms	remaining: 42.2s
# 1:	learn: 0.6889415	total: 269ms	remaining: 40s
# 2:	learn: 0.6869606	total: 400ms	remaining: 39.6s
# 3:	learn: 0.6849453	total: 527ms	remaining: 39s
# 4:	learn: 0.6829604	total: 654ms	remaining: 38.6s
# 5:	learn: 0.6809941	total: 796ms	remaining: 39s
# 6:	learn: 0.6790596	total: 922ms	remaining: 38.6s
# 7:	learn: 0.6771836	total: 1.04s	remaining: 38.1s
# 8:	learn: 0.6753624	total: 1.17s	remaining: 37.8s
# 9:	learn: 0.6735534	total: 1.3s	remaining: 37.6s
# 10:	learn: 0.6717651	total: 1.43s	remaining: 37.5s
# 11:	learn: 0.6701315	total: 1.56s	remaining: 37.4s
# 12:	learn: 0.6684213	total: 1.68s	remaining: 37.2s
# 13:	learn: 0.6667757	total: 1.84s	remaining: 37.7s
# 14:	learn: 0.6651576	total: 1.97s	remaining: 37.5s
# 15:	learn: 0.6635297	total: 2.11s	remaining: 37.5s
# 16:	learn: 0.6619532	total: 2.25s	remaining: 37.4s
# 17:	learn: 0.6603719	total: 2.37s	remaining: 37.1s
# 18:	learn: 0.6588470	total: 2.5s	remaining: 37s
# 19:	learn: 0.6573667	total: 2.62s	remaining: 36.7s
# 20:	learn: 0.6558960	total: 2.75s	remaining: 36.6s
# 21:	learn: 0.6544118	total: 2.89s	remaining: 36.5s
# 22:	learn: 0.6530489	total: 3.01s	remaining: 36.3s
# 23:	learn: 0.6516464	total: 3.14s	remaining: 36.2s
# 24:	learn: 0.6502596	total: 3.27s	remaining: 36s
# 25:	learn: 0.6489017	total: 3.39s	remaining: 35.8s
# 26:	learn: 0.6475917	total: 3.53s	remaining: 35.7s
# 27:	learn: 0.6463011	total: 3.65s	remaining: 35.4s
# 28:	learn: 0.6449781	total: 3.78s	remaining: 35.3s
# 29:	learn: 0.6436487	total: 3.92s	remaining: 35.3s
# 30:	learn: 0.6424094	total: 4.05s	remaining: 35.1s
# 31:	learn: 0.6411580	total: 4.17s	remaining: 34.9s
# 32:	learn: 0.6399896	total: 4.39s	remaining: 35.5s
# 33:	learn: 0.6387851	total: 4.84s	remaining: 37.9s
# 34:	learn: 0.6375918	total: 5.13s	remaining: 38.8s
# 35:	learn: 0.6364096	total: 5.25s	remaining: 38.5s
# 36:	learn: 0.6352700	total: 5.39s	remaining: 38.3s
# 37:	learn: 0.6341935	total: 5.52s	remaining: 38.1s
# 38:	learn: 0.6330911	total: 5.65s	remaining: 37.8s
# 39:	learn: 0.6319770	total: 5.77s	remaining: 37.5s
# 40:	learn: 0.6308962	total: 5.91s	remaining: 37.3s
# 41:	learn: 0.6298549	total: 6.06s	remaining: 37.2s
# 42:	learn: 0.6288205	total: 6.2s	remaining: 37.1s
# 43:	learn: 0.6277990	total: 6.33s	remaining: 36.8s
# 44:	learn: 0.6268096	total: 6.46s	remaining: 36.6s
# 45:	learn: 0.6258217	total: 6.59s	remaining: 36.4s
# 46:	learn: 0.6248352	total: 6.72s	remaining: 36.2s
# 47:	learn: 0.6239050	total: 6.9s	remaining: 36.2s
# 48:	learn: 0.6229754	total: 7.11s	remaining: 36.4s
# 49:	learn: 0.6221008	total: 7.35s	remaining: 36.8s
# 50:	learn: 0.6211880	total: 7.61s	remaining: 37.2s
# 51:	learn: 0.6202927	total: 7.87s	remaining: 37.5s
# 52:	learn: 0.6194166	total: 8.13s	remaining: 37.9s
# 53:	learn: 0.6185538	total: 8.38s	remaining: 38.2s
# 54:	learn: 0.6177701	total: 8.65s	remaining: 38.5s
# 55:	learn: 0.6170012	total: 8.89s	remaining: 38.8s
# 56:	learn: 0.6161730	total: 9.16s	remaining: 39.1s
# 57:	learn: 0.6153778	total: 9.43s	remaining: 39.4s
# 58:	learn: 0.6145834	total: 9.68s	remaining: 39.6s
# 59:	learn: 0.6138135	total: 9.94s	remaining: 39.7s
# 60:	learn: 0.6130270	total: 10.2s	remaining: 40s
# 61:	learn: 0.6122484	total: 10.5s	remaining: 40.1s
# 62:	learn: 0.6115170	total: 10.7s	remaining: 40.4s
# 63:	learn: 0.6107773	total: 11s	remaining: 40.5s
# 64:	learn: 0.6100633	total: 11.3s	remaining: 40.7s
# 65:	learn: 0.6093431	total: 11.5s	remaining: 40.8s
# 66:	learn: 0.6086440	total: 11.8s	remaining: 40.9s
# 67:	learn: 0.6079185	total: 12s	remaining: 41.1s
# 68:	learn: 0.6072501	total: 12.3s	remaining: 41.1s
# 69:	learn: 0.6065703	total: 12.6s	remaining: 41.3s
# 70:	learn: 0.6058628	total: 12.8s	remaining: 41.4s
# 71:	learn: 0.6051825	total: 13.1s	remaining: 41.5s
# 72:	learn: 0.6045367	total: 13.3s	remaining: 41.5s
# 73:	learn: 0.6039605	total: 13.6s	remaining: 41.5s
# 74:	learn: 0.6033551	total: 13.8s	remaining: 41.5s
# 75:	learn: 0.6027150	total: 14s	remaining: 41.3s
# 76:	learn: 0.6021010	total: 14.1s	remaining: 41s
# 77:	learn: 0.6014730	total: 14.3s	remaining: 40.6s
# 78:	learn: 0.6008854	total: 14.4s	remaining: 40.3s
# 79:	learn: 0.6003461	total: 14.5s	remaining: 40s
# 80:	learn: 0.5997691	total: 14.7s	remaining: 39.7s
# 81:	learn: 0.5992090	total: 14.8s	remaining: 39.3s
# 82:	learn: 0.5986475	total: 14.9s	remaining: 39s
# 83:	learn: 0.5980518	total: 15s	remaining: 38.7s
# 84:	learn: 0.5975019	total: 15.2s	remaining: 38.4s
# 85:	learn: 0.5969681	total: 15.3s	remaining: 38s
# 86:	learn: 0.5964322	total: 15.4s	remaining: 37.8s
# 87:	learn: 0.5958872	total: 15.6s	remaining: 37.5s
# 88:	learn: 0.5954025	total: 15.7s	remaining: 37.2s
# 89:	learn: 0.5949120	total: 15.8s	remaining: 36.9s
# 90:	learn: 0.5943713	total: 15.9s	remaining: 36.6s
# 91:	learn: 0.5938485	total: 16.1s	remaining: 36.3s
# 92:	learn: 0.5933544	total: 16.2s	remaining: 36.1s
# 93:	learn: 0.5928962	total: 16.3s	remaining: 35.8s
# 94:	learn: 0.5923855	total: 16.5s	remaining: 35.5s
# 95:	learn: 0.5919032	total: 16.6s	remaining: 35.3s
# 96:	learn: 0.5915015	total: 16.7s	remaining: 35s
# 97:	learn: 0.5910711	total: 16.9s	remaining: 34.7s
# 98:	learn: 0.5906282	total: 17s	remaining: 34.5s
# 99:	learn: 0.5901843	total: 17.1s	remaining: 34.2s
# 100:	learn: 0.5896911	total: 17.2s	remaining: 34s
# 101:	learn: 0.5892240	total: 17.4s	remaining: 33.7s
# 102:	learn: 0.5888083	total: 17.5s	remaining: 33.5s
# 103:	learn: 0.5883925	total: 17.6s	remaining: 33.2s
# 104:	learn: 0.5880291	total: 17.8s	remaining: 33s
# 105:	learn: 0.5875989	total: 17.9s	remaining: 32.7s
# 106:	learn: 0.5872308	total: 18s	remaining: 32.5s
# 107:	learn: 0.5868630	total: 18.1s	remaining: 32.3s
# 108:	learn: 0.5865225	total: 18.3s	remaining: 32s
# 109:	learn: 0.5861506	total: 18.4s	remaining: 31.8s
# 110:	learn: 0.5857899	total: 18.5s	remaining: 31.6s
# 111:	learn: 0.5853756	total: 18.7s	remaining: 31.3s
# 112:	learn: 0.5850228	total: 18.8s	remaining: 31.1s
# 113:	learn: 0.5846656	total: 18.9s	remaining: 30.9s
# 114:	learn: 0.5843458	total: 19.1s	remaining: 30.7s
# 115:	learn: 0.5839618	total: 19.2s	remaining: 30.4s
# 116:	learn: 0.5835767	total: 19.3s	remaining: 30.2s
# 117:	learn: 0.5832160	total: 19.4s	remaining: 30s
# 118:	learn: 0.5828625	total: 19.6s	remaining: 29.8s
# 119:	learn: 0.5825578	total: 19.7s	remaining: 29.6s
# 120:	learn: 0.5822456	total: 19.8s	remaining: 29.3s
# 121:	learn: 0.5819035	total: 20s	remaining: 29.1s
# 122:	learn: 0.5815232	total: 20.1s	remaining: 28.9s
# 123:	learn: 0.5812125	total: 20.2s	remaining: 28.7s
# 124:	learn: 0.5809122	total: 20.3s	remaining: 28.5s
# 125:	learn: 0.5806355	total: 20.5s	remaining: 28.3s
# 126:	learn: 0.5802993	total: 20.6s	remaining: 28.1s
# 127:	learn: 0.5799397	total: 20.7s	remaining: 27.9s
# 128:	learn: 0.5796814	total: 20.9s	remaining: 27.7s
# 129:	learn: 0.5793965	total: 21s	remaining: 27.5s
# 130:	learn: 0.5791266	total: 21.1s	remaining: 27.3s
# 131:	learn: 0.5787993	total: 21.3s	remaining: 27s
# 132:	learn: 0.5785256	total: 21.4s	remaining: 26.9s
# 133:	learn: 0.5782386	total: 21.5s	remaining: 26.7s
# 134:	learn: 0.5779952	total: 21.6s	remaining: 26.4s
# 135:	learn: 0.5777254	total: 21.8s	remaining: 26.3s
# 136:	learn: 0.5774213	total: 21.9s	remaining: 26.1s
# 137:	learn: 0.5771099	total: 22s	remaining: 25.9s
# 138:	learn: 0.5768231	total: 22.2s	remaining: 25.7s
# 139:	learn: 0.5765494	total: 22.3s	remaining: 25.5s
# 140:	learn: 0.5762966	total: 22.4s	remaining: 25.3s
# 141:	learn: 0.5760634	total: 22.6s	remaining: 25.1s
# 142:	learn: 0.5757952	total: 22.7s	remaining: 24.9s
# 143:	learn: 0.5755601	total: 22.8s	remaining: 24.7s
# 144:	learn: 0.5752533	total: 23s	remaining: 24.5s
# 145:	learn: 0.5749683	total: 23.1s	remaining: 24.3s
# 146:	learn: 0.5747510	total: 23.2s	remaining: 24.2s
# 147:	learn: 0.5744930	total: 23.3s	remaining: 24s
# 148:	learn: 0.5742753	total: 23.5s	remaining: 23.8s
# 149:	learn: 0.5740198	total: 23.6s	remaining: 23.6s
# 150:	learn: 0.5738375	total: 23.7s	remaining: 23.4s
# 151:	learn: 0.5735851	total: 23.9s	remaining: 23.2s
# 152:	learn: 0.5733337	total: 24s	remaining: 23.1s
# 153:	learn: 0.5730704	total: 24.2s	remaining: 23s
# 154:	learn: 0.5728317	total: 24.5s	remaining: 22.9s
# 155:	learn: 0.5725700	total: 24.7s	remaining: 22.8s
# 156:	learn: 0.5723095	total: 25s	remaining: 22.7s
# 157:	learn: 0.5721239	total: 25.2s	remaining: 22.6s
# 158:	learn: 0.5719179	total: 25.4s	remaining: 22.6s
# 159:	learn: 0.5716947	total: 25.7s	remaining: 22.4s
# 160:	learn: 0.5715294	total: 25.9s	remaining: 22.3s
# 161:	learn: 0.5713319	total: 26.1s	remaining: 22.3s
# 162:	learn: 0.5710999	total: 26.3s	remaining: 22.1s
# 163:	learn: 0.5708638	total: 26.6s	remaining: 22s
# 164:	learn: 0.5706537	total: 26.8s	remaining: 21.9s
# 165:	learn: 0.5704580	total: 27s	remaining: 21.8s
# 166:	learn: 0.5702886	total: 27.3s	remaining: 21.7s
# 167:	learn: 0.5701147	total: 27.5s	remaining: 21.6s
# 168:	learn: 0.5699016	total: 27.7s	remaining: 21.5s
# 169:	learn: 0.5696904	total: 27.9s	remaining: 21.3s
# 170:	learn: 0.5695222	total: 28.1s	remaining: 21.2s
# 171:	learn: 0.5693671	total: 28.3s	remaining: 21.1s
# 172:	learn: 0.5692177	total: 28.6s	remaining: 21s
# 173:	learn: 0.5690337	total: 28.8s	remaining: 20.9s
# 174:	learn: 0.5688355	total: 29.1s	remaining: 20.8s
# 175:	learn: 0.5686206	total: 29.3s	remaining: 20.6s
# 176:	learn: 0.5684299	total: 29.5s	remaining: 20.5s
# 177:	learn: 0.5682501	total: 29.8s	remaining: 20.4s
# 178:	learn: 0.5680731	total: 30s	remaining: 20.3s
# 179:	learn: 0.5678672	total: 30.3s	remaining: 20.2s
# 180:	learn: 0.5677104	total: 30.5s	remaining: 20.1s
# 181:	learn: 0.5675166	total: 30.7s	remaining: 19.9s
# 182:	learn: 0.5673394	total: 30.9s	remaining: 19.8s
# 183:	learn: 0.5671663	total: 31.2s	remaining: 19.6s
# 184:	learn: 0.5669789	total: 31.4s	remaining: 19.5s
# 185:	learn: 0.5667944	total: 31.6s	remaining: 19.4s
# 186:	learn: 0.5666514	total: 31.8s	remaining: 19.2s
# 187:	learn: 0.5664759	total: 31.9s	remaining: 19s
# 188:	learn: 0.5662794	total: 32s	remaining: 18.8s
# 189:	learn: 0.5661081	total: 32.1s	remaining: 18.6s
# 190:	learn: 0.5659725	total: 32.3s	remaining: 18.4s
# 191:	learn: 0.5658283	total: 32.4s	remaining: 18.2s
# 192:	learn: 0.5656537	total: 32.5s	remaining: 18s
# 193:	learn: 0.5654748	total: 32.7s	remaining: 17.8s
# 194:	learn: 0.5653275	total: 32.8s	remaining: 17.7s
# 195:	learn: 0.5651535	total: 32.9s	remaining: 17.5s
# 196:	learn: 0.5649900	total: 33s	remaining: 17.3s
# 197:	learn: 0.5648938	total: 33.2s	remaining: 17.1s
# 198:	learn: 0.5647108	total: 33.3s	remaining: 16.9s
# 199:	learn: 0.5645573	total: 33.5s	remaining: 16.7s
# 200:	learn: 0.5644319	total: 33.6s	remaining: 16.5s
# 201:	learn: 0.5642720	total: 33.7s	remaining: 16.4s
# 202:	learn: 0.5641275	total: 33.8s	remaining: 16.2s
# 203:	learn: 0.5639576	total: 34s	remaining: 16s
# 204:	learn: 0.5637788	total: 34.1s	remaining: 15.8s
# 205:	learn: 0.5636545	total: 34.2s	remaining: 15.6s
# 206:	learn: 0.5634754	total: 34.4s	remaining: 15.4s
# 207:	learn: 0.5633552	total: 34.5s	remaining: 15.3s
# 208:	learn: 0.5631982	total: 34.6s	remaining: 15.1s
# 209:	learn: 0.5630624	total: 34.7s	remaining: 14.9s
# 210:	learn: 0.5629029	total: 34.9s	remaining: 14.7s
# 211:	learn: 0.5627809	total: 35s	remaining: 14.5s
# 212:	learn: 0.5626479	total: 35.1s	remaining: 14.3s
# 213:	learn: 0.5625054	total: 35.2s	remaining: 14.2s
# 214:	learn: 0.5623627	total: 35.4s	remaining: 14s
# 215:	learn: 0.5622109	total: 35.5s	remaining: 13.8s
# 216:	learn: 0.5620814	total: 35.7s	remaining: 13.6s
# 217:	learn: 0.5619576	total: 35.8s	remaining: 13.5s
# 218:	learn: 0.5618250	total: 35.9s	remaining: 13.3s
# 219:	learn: 0.5616804	total: 36s	remaining: 13.1s
# 220:	learn: 0.5615425	total: 36.2s	remaining: 12.9s
# 221:	learn: 0.5614010	total: 36.3s	remaining: 12.7s
# 222:	learn: 0.5612742	total: 36.4s	remaining: 12.6s
# 223:	learn: 0.5611160	total: 36.5s	remaining: 12.4s
# 224:	learn: 0.5609998	total: 36.7s	remaining: 12.2s
# 225:	learn: 0.5608651	total: 36.8s	remaining: 12s
# 226:	learn: 0.5607292	total: 36.9s	remaining: 11.9s
# 227:	learn: 0.5605933	total: 37.1s	remaining: 11.7s
# 228:	learn: 0.5604522	total: 37.2s	remaining: 11.5s
# 229:	learn: 0.5603323	total: 37.3s	remaining: 11.4s
# 230:	learn: 0.5601874	total: 37.4s	remaining: 11.2s
# 231:	learn: 0.5600567	total: 37.6s	remaining: 11s
# 232:	learn: 0.5599376	total: 37.7s	remaining: 10.8s
# 233:	learn: 0.5598036	total: 37.9s	remaining: 10.7s
# 234:	learn: 0.5596862	total: 38.1s	remaining: 10.5s
# 235:	learn: 0.5595574	total: 38.4s	remaining: 10.4s
# 236:	learn: 0.5594391	total: 38.6s	remaining: 10.3s
# 237:	learn: 0.5593350	total: 38.8s	remaining: 10.1s
# 238:	learn: 0.5591860	total: 39.1s	remaining: 9.98s
# 239:	learn: 0.5590567	total: 39.3s	remaining: 9.83s
# 240:	learn: 0.5589091	total: 39.5s	remaining: 9.68s
# 241:	learn: 0.5587934	total: 39.8s	remaining: 9.53s
# 242:	learn: 0.5586906	total: 40s	remaining: 9.38s
# 243:	learn: 0.5585848	total: 40.2s	remaining: 9.23s
# 244:	learn: 0.5584406	total: 40.5s	remaining: 9.09s
# 245:	learn: 0.5583394	total: 40.7s	remaining: 8.94s
# 246:	learn: 0.5582159	total: 41s	remaining: 8.79s
# 247:	learn: 0.5580746	total: 41.2s	remaining: 8.64s
# 248:	learn: 0.5579688	total: 41.4s	remaining: 8.48s
# 249:	learn: 0.5578402	total: 41.5s	remaining: 8.31s
# 250:	learn: 0.5577050	total: 41.7s	remaining: 8.14s
# 251:	learn: 0.5576155	total: 41.8s	remaining: 7.96s
# 252:	learn: 0.5575013	total: 41.9s	remaining: 7.79s
# 253:	learn: 0.5573601	total: 42.1s	remaining: 7.62s
# 254:	learn: 0.5572617	total: 42.2s	remaining: 7.45s
# 255:	learn: 0.5571799	total: 42.3s	remaining: 7.27s
# 256:	learn: 0.5570511	total: 42.4s	remaining: 7.1s
# 257:	learn: 0.5569338	total: 42.6s	remaining: 6.93s
# 258:	learn: 0.5568240	total: 42.7s	remaining: 6.76s
# 259:	learn: 0.5566926	total: 42.8s	remaining: 6.59s
# 260:	learn: 0.5566089	total: 42.9s	remaining: 6.42s
# 261:	learn: 0.5565144	total: 43.1s	remaining: 6.25s
# 262:	learn: 0.5564079	total: 43.2s	remaining: 6.08s
# 263:	learn: 0.5562860	total: 43.3s	remaining: 5.91s
# 264:	learn: 0.5561686	total: 43.5s	remaining: 5.74s
# 265:	learn: 0.5560865	total: 43.6s	remaining: 5.57s
# 266:	learn: 0.5559844	total: 43.7s	remaining: 5.41s
# 267:	learn: 0.5558633	total: 43.9s	remaining: 5.24s
# 268:	learn: 0.5557766	total: 44s	remaining: 5.07s
# 269:	learn: 0.5556813	total: 44.1s	remaining: 4.9s
# 270:	learn: 0.5555700	total: 44.2s	remaining: 4.73s
# 271:	learn: 0.5554911	total: 44.4s	remaining: 4.57s
# 272:	learn: 0.5553658	total: 44.5s	remaining: 4.4s
# 273:	learn: 0.5552268	total: 44.6s	remaining: 4.23s
# 274:	learn: 0.5551155	total: 44.8s	remaining: 4.07s
# 275:	learn: 0.5550152	total: 44.9s	remaining: 3.9s
# 276:	learn: 0.5549036	total: 45s	remaining: 3.74s
# 277:	learn: 0.5548143	total: 45.1s	remaining: 3.57s
# 278:	learn: 0.5547176	total: 45.3s	remaining: 3.41s
# 279:	learn: 0.5546066	total: 45.4s	remaining: 3.24s
# 280:	learn: 0.5545277	total: 45.5s	remaining: 3.08s
# 281:	learn: 0.5544053	total: 45.6s	remaining: 2.91s
# 282:	learn: 0.5543206	total: 45.8s	remaining: 2.75s
# 283:	learn: 0.5542110	total: 45.9s	remaining: 2.59s
# 284:	learn: 0.5540947	total: 46s	remaining: 2.42s
# 285:	learn: 0.5539776	total: 46.2s	remaining: 2.26s
# 286:	learn: 0.5538568	total: 46.3s	remaining: 2.1s
# 287:	learn: 0.5537336	total: 46.4s	remaining: 1.93s
# 288:	learn: 0.5535875	total: 46.5s	remaining: 1.77s
# 289:	learn: 0.5534982	total: 46.7s	remaining: 1.61s
# 290:	learn: 0.5534265	total: 46.8s	remaining: 1.45s
# 291:	learn: 0.5533526	total: 46.9s	remaining: 1.29s
# 292:	learn: 0.5532787	total: 47.1s	remaining: 1.12s
# 293:	learn: 0.5531895	total: 47.2s	remaining: 963ms
# 294:	learn: 0.5531151	total: 47.3s	remaining: 802ms
# 295:	learn: 0.5530364	total: 47.4s	remaining: 641ms
# 296:	learn: 0.5529547	total: 47.6s	remaining: 481ms
# 297:	learn: 0.5528720	total: 47.7s	remaining: 320ms
# 298:	learn: 0.5528072	total: 47.8s	remaining: 160ms
# 299:	learn: 0.5527026	total: 48s	remaining: 0us
# test report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.51      0.60      5275
#            1       0.67      0.74      0.70      5286
#            2       0.68      0.76      0.72      9439
#
#     accuracy                           0.69     20000
#    macro avg       0.70      0.67      0.68     20000
# weighted avg       0.69      0.69      0.68     20000
#
# train report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70     31346
#            1       0.68      0.77      0.72     23836
#            2       0.69      0.71      0.70     41466
#
#     accuracy                           0.70     96648
#    macro avg       0.71      0.71      0.71     96648
# weighted avg       0.71      0.70      0.70     96648

# %% [markdown]
# # Voting Ensemble

# %%
def ensemble_predictor(dataset=None, target_labels=None, model_lookup=models_and_reports,
                       predictors=None, use_weights=False, scoring_metric='precision'):
    """
    Performs weighted/mojority ensemble predictions using multiple classifiers. This function aggregates predictions
    from various classifiers defined in `model_lookup` (whcih must also be present in the 'models_and_reports' dictionary)
    based on a specified scoring metric.

    Parameters:
        dataset - Dataframe with the input dataset for which predictions are to be made.
        target_labels - Series with the actual labels for the dataset, used for calculating accuracy.
        model_lookup - A dictionary with model names as keys with tuples (model_pipeline, performance_report) as values.
        predictors - List of model names specifically to be used for prediction. If None, all models in `model_lookup` are employed.
        use_weights - Toggles whether to use weighted predictions based on `scoring_metric`.
        scoring_metric - Performance metric used to determine weights from model performance reports. Default is set to 'precision'.

    Returns:
        Union - A dataframe with weighted or majority voted predictions depending on `use_weights`.
        When `target_labels` is provided, also prints accuracy and classification report.

    """
    baseline_predictions = pd.DataFrame()
    model_weights = pd.DataFrame()
    final_predictions = pd.DataFrame()

    if predictors is None:
        predictors = model_lookup.keys()

    for idx, model in enumerate(predictors):
        if idx == 0:
            baseline_predictions = pd.DataFrame({str(model): model_lookup[model][0].predict(dataset)})
            if use_weights:
                model_weights = pd.DataFrame({str(model): model_lookup[model][-1].T[scoring_metric][:3]})
        else:
            baseline_predictions[str(model)] = model_lookup[model][0].predict(dataset)
            if use_weights:
                model_weights[str(model)] = model_lookup[model][-1].T[scoring_metric][:3]

    if use_weights:
        for model_idx, model_name in enumerate(baseline_predictions):
            model_weighted_factor = pd.get_dummies(baseline_predictions[model_name]) * model_weights[model_name][-1].tolist()
            if model_idx == 0:
                final_predictions = model_weighted_factor
            else:
                final_predictions += model_weighted_factor

        print(final_predictions.head(5))
        weighted_votes = np.argmax(final_predictions.to_numpy(), axis=1)

        if target_labels is not None:
            accuracy = np.mean(weighted_votes == target_labels)
            print(f'Weighted (by {scoring_metric}) prediction accuracy: {accuracy}\n'
                  f'{classification_report(weighted_votes, target_labels)}')

        return weighted_votes

    else:
        majority_votes = baseline_predictions.mode(axis=1)[0].to_numpy()
        if target_labels is not None:
            accuracy = np.mean(majority_votes == target_labels) # comparing baseline predictins with target labels
            print(f'Unweighted prediction accuracy: {accuracy}'
                  f'\n{classification_report(majority_votes, target_labels)}')
        return pd.DataFrame(majority_votes)

# %%
main_metric='f1-score'

y = df['Credit_Score']
X = df.drop('Credit_Score', axis=1)  # Replace 'label_column_name' with the actual column name of the label

estim_list = ['RandomForestClassifier','XGBoost','OneVsRestClassifier', 'CatBoostClassifier']
x_train, x_test, y_train, y_test = split_and_rebalance(df, 0.2)
weighted_pre=ensemble_predictor(dataset=x_test, target_labels=y_test, model_lookup=models_and_reports,
                       predictors=estim_list, use_weights=True, scoring_metric=main_metric)
# Out:
# Credit_Score
# 2    42648
# 0    27000
# 1    27000
# Name: count, dtype: int64
#           0         1         2
# 0  0.000000  3.082632  0.000000
# 1  0.000000  1.482713  1.599919
# 2  3.082632  0.000000  0.000000
# 3  1.599919  0.000000  1.482713
# 4  0.000000  0.000000  3.082632
# Weighted (by f1-score) prediction accuracy: 0.78905
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73      4400
#            1       0.83      0.79      0.81      6143
#            2       0.76      0.84      0.80      9457
#
#     accuracy                           0.79     20000
#    macro avg       0.80      0.77      0.78     20000
# weighted avg       0.79      0.79      0.79     20000

# %%
# End of the Notebbok
